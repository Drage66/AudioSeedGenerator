# %%
import matplotlib.pyplot as plt
import matplotlib.cbook as cbook

import numpy as np
import pandas as pd

# %%
# sep_csv = pd.read_csv('septemberSamples.csv')
sstv_csv = pd.read_csv('sstv.csv')

# %%
# display(len(sep_csv))
# display(sstv_csv)
spacing = 10
x = np.arange(0,len(sstv_csv) * spacing,spacing)
x = pd.DataFrame(x)
plt.figure(figsize=(16,9))
plt.plot(x,sstv_csv * spacing)
plt.show()
